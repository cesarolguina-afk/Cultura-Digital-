# %% [markdown]
# # Tarea: Uso de Condicionales (if / else)

# %% [markdown]
# ## Parte 1: Condicionales en la vida diaria
# Escribe 3 oraciones de situaciones reales donde usarías un "si... entonces...".
#
# Ejemplo:
# Si me despierto tarde, entonces llego tarde a la escuela.
#
# 1.si me baño en la noche no se me seca el pelo
# 2.si me baño en la mañana me enfermo
# 3.si me baño en la tarde es mejor

# %% [markdown]
# ## Parte 2: Explicación de la importancia de las condicionales
# Explica 4 ejemplos donde se vea por qué son necesarias las condicionales.
#
# Ejemplo modelo:
#
#
# *   Situación: Decidir si llevo paraguas.
# *   Condición: Si está lloviendo.
# *   Si se cumple: Llevo paraguas.
# *   Si no se cumple: Salgo sin paraguas.
#
#
#
# 1.
# *   Situación:decidir si llevo sueter
# *   Condición:si hace frio
# *   Si se cumple:llevo sueter
# *   Si no se cumple:no llevo sueter
#
# 2.
# *   Situación:hacer la tarea el domingo
# *   Condición:si no tengo tiempo
# *   Si se cumple:la hago el domingo
# *   Si no se cumple:la hago antes
#
# 3.
# *   Situación:ver fnaf2 en el cine
# *   Condición:si tengo dinero
# *   Si se cumple:veo fnaf2
# *   Si no se cumple:no veo fnaf2
#
# 4.
# *   Situación:comer quesadillas 2x1
# *   Condición:si es martes de promocion
# *   Si se cumple:como 2 por el precio de una
# *   Si no se cumple:pago las 2 a su precio

# %% [markdown]
# ## Parte 3: Condicionales en Python

# %% [markdown]
# ### Ejercicio 1
# Pide la hora (0-23). Si es menor que 12 muestra 'Es mañana', si no 'Es tarde o noche'.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 2
# Pide dos números y muestra cuál es mayor o si son iguales.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 3
# Pide un número entero y muestra si es par o impar.

# %%
# Escribe tu código aquí
